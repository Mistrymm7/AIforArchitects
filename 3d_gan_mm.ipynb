# %% [markdown]
# <a href="https://colab.research.google.com/github/Mistrymm7/AIforArchitects/blob/master/3d_gan_mm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/3d-gan-mm
# Out:
# /content/drive/MyDrive/3d-gan-mm

# %%
ls
# Out:
# discriminative_10_class.mat  image.png       README.md         run.py
# image/                       mm_3dgan.ipynb  requirements.txt  visualize.mat

# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 102kB 6.3MB/s
# ...
#      |████████████████████████████████| 163kB 18.1MB/s
# ...
#      |████████████████████████████████| 686kB 22.5MB/s
# ...
#      |████████████████████████████████| 10.1MB 21.5MB/s
# ...
#      |████████████████████████████████| 2.8MB 52.3MB/s
# ...
#      |████████████████████████████████| 61kB 6.2MB/s
# ...
#      |████████████████████████████████| 317kB 54.2MB/s
# ...
#      |████████████████████████████████| 51kB 5.5MB/s
# ...
#      |████████████████████████████████| 952kB 46.5MB/s
# ...
#      |████████████████████████████████| 92kB 9.1MB/s
# ...
#      |████████████████████████████████| 12.9MB 29.1MB/s
# ...
#      |████████████████████████████████| 1.7MB 35.3MB/s
# ...
#      |████████████████████████████████| 13.9MB 322kB/s
# ...
#      |████████████████████████████████| 2.0MB 50.8MB/s
# ...
#      |████████████████████████████████| 1.1MB 48.5MB/s
# ...
#      |████████████████████████████████| 61kB 6.1MB/s
# ...
#      |████████████████████████████████| 235kB 54.4MB/s
# ...

# %%
import scipy.io as io
#voxels = io.loadmat("discriminative_10_class.mat")['instance']
voxels = io.loadmat("discriminative_10_class.mat")

# %%
print(voxels)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue May 26 16:19:18 2015', '__version__': '1.0', '__globals__': [], 'model': array([[(array([[6]], dtype=uint8), array([[10]], dtype=uint8), array([[array([[(array(['input'], dtype='<U5'), array([[30, 30, 30,  1]], dtype=uint8))]],
#       dtype=[('type', 'O'), ('layerSize', 'O')])],
#        [array([[(array(['convolution'], dtype='<U11'), array(['sigmoid'], dtype='<U7'), array([[2]], dtype=uint8), array([[13, 13, 13, 80]], dtype=uint8), array([[6, 6, 6]], dtype=uint8), array([[[[ 6.03446066e-02,  6.09269030e-02, -8.75264332e-02,
#           -7.54938498e-02, -6.65164413e-03,  2.59489343e-02],
#          [ 6.89429864e-02,  6.34215176e-02, -9.10528526e-02,
#           -8.03478956e-02, -8.73237196e-03,  1.88512765e-02],
#          [ 8.27089921e-02,  7.40957856e-02, -9.69275832e-02,
#           -8.66434053e-02, -9.06684436e-03,  2.02219151e-02],
#          [ 8.15130100e-02,  6.89936653e-02, -9.47147384e-02,
# ...

# %%
ls
# Out:
# image/     mm_3dgan.ipynb  requirements.txt  visualize.mat
# image.png  README.md       run.py

# %%
import numpy as np
voxels = np.pad(voxels, (1,1),'constant', constant_values=(0,0))

# %%
import scipy.ndimage as nd
voxels = nd.zoom(voxels,(2,2,2),mode='constant', order=3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-64b6d023d575> in <module>()
#       1 import scipy.ndimage as nd
# ----> 2 voxels = nd.zoom(voxels,(2,2,2),mode='constant', order=3)
#
# /usr/local/lib/python3.6/dist-packages/scipy/ndimage/interpolation.py in zoom(input, zoom, output, order, mode, cval, prefilter)
#     587         raise TypeError('Complex type not supported')
#     588     if input.ndim < 1:
# --> 589         raise RuntimeError('input and output rank must be > 0')
#     590     mode = _ni_support._extend_mode_to_code(mode)
#     591     if prefilter and order > 1:
#
# RuntimeError: input and output rank must be > 0

# %% [markdown]
# Edited original **code** (plt error, projection 3d error)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # <--- This is important for 3d plotting

# %%
fig = plt.figure()
ax= fig.gca(projection='3d')
ax.set_aspect('equal')

# %%
ax.voxels(voxels,edgecolor='red')
plt.show()
plt.savefig("/content/drive/MyDrive/3d-gan-mm/image")
